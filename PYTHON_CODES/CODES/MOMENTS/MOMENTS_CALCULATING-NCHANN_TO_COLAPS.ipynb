# %% [markdown]
# # Calculate MOMENTS (define specifict number of channels)
#
# - Define the channel to colapse
# - Define the range of velocity
#
# __No Genering the masking intensities__

# %%
# Packages to calculate the moments
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy import units as u
from astropy.wcs import WCS
from astropy import constants as const
from spectral_cube import SpectralCube
from astropy.coordinates import SkyCoord
from tqdm import tqdm
import copy

# %%
#--------------- Define the parameters -------------------
# Define the path to the data cubes
file1 = 'C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/RESULTS/FITS/CORRECT/CII/CII_N159_SPAT_RES.fits'
file2 = 'C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/RESULTS/FITS/CORRECT/CF+/CF+_N159_sci_VELAXIS_inK_SPECT_SPAT_RES.fits'

# Read the data cubes
cube1 = SpectralCube.read(file1)
cube2 = SpectralCube.read(file2)
print(cube1.header)
print(cube2.header)
#------------- Define the parameters for the moments calculation -------------------

nchan = 3  # Number of channels to collapse
vel_min = 190 * u.km / u.s # Minimum velocity
vel_max = 260 * u.km / u.s # Maximum velocity
order = 0  # Order of the moment (0 for intensity, 1 for velocity, 2 for dispersion)
print('Parameters for the moments calculation:')
print(f'Number of channels: {nchan}')
print(f'Velocity range: {vel_min} to {vel_max}')

# ------------- Define the output file names ---------------------
output_file1 = f'C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/CODES/TEST/moments_cube1_nchan{nchan}.fits'
output_file2 = f'C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/CODES/TEST/moments_cube2_nchan{nchan}.fits'

# Diferent output to other quantitie of channel to
#output_file1 = 'C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/RESULTS/FITS/TESTS/moments__cube1_nch5.fits'
#output_file2 = 'C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/RESULTS/FITS/TESTS/moments__cube2_nch5.fits'
# Out:
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -64 / array data type                                NAXIS   =                    3                                                  NAXIS1  =                   70                                                  NAXIS2  =                   60                                                  NAXIS3  =                  300                                                  RESTFRQ =                  0.0                                                  VELREF  =                    0                                                  BMAJ    = 0.004444444444444444                                                  BMIN    = 0.004444444444444444                                                  BPA     =                  0.0                                                  BUNIT   = 'K       '           / Brightness unit in Kelvin                      BEAM    = 'Beam: BMAJ=15.999999999999996 arcsec BMIN=15.999999999999996 &'      CONTINUE  'arcsec BPA=0.0 deg'                                                  WCSAXES =                    3 / Number of coordinate axes                      CRPIX1  =      43.505224439404 / Pixel coordinate of reference point            CRPIX2  =      32.760800801165 / Pixel coordinate of reference point            CRPIX3  =                150.0 / Pixel coordinate of reference point            CDELT1  =    -0.00148148147855 / [deg] Coordinate increment at reference point  CDELT2  =     0.00148148147855 / [deg] Coordinate increment at reference point  CDELT3  =                  1.0 / [m/s] Coordinate increment at reference point  CUNIT1  = 'deg'                / Units of coordinate increment and value        CUNIT2  = 'deg'                / Units of coordinate increment and value        CUNIT3  = 'km s-1  '           / Units of coordinate increment and value        CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection           CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection               CTYPE3  = 'VELO'               / Relativistic velocity (linear)                 CRVAL1  =      84.909230273958 / [deg] Coordinate value at reference point      CRVAL2  =     -69.760160218056 / [deg] Coordinate value at reference point      CRVAL3  =                187.0 / [m/s] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =     -69.760160218056 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = 'ICRS'               / Equatorial coordinate system                   COMMENT Original Unit=m / s                                                     COMMENT Original Type=VELO                                                      HISTORY Written by spectral_cube v0.6.6 on 2025/08/28-12:49:25                  END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -64 / array data type                                NAXIS   =                    3                                                  NAXIS1  =                   70                                                  NAXIS2  =                   60                                                  NAXIS3  =                  729                                                  BMAJ    = 0.004444444444444444                                                  BMIN    = 0.004444444444444444                                                  BPA     =                  0.0                                                  BTYPE   = 'Intensity'                                                           OBJECT  = 'N159-13CII'                                                          BUNIT   = 'K       '           / Brightness unit in Jy/beam                     ALTRVAL =   5.990705566226E+05 /Alternate frequency reference value             ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel             VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio                 COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL                 COMMENT Original Unit=Hz                                                        COMMENT Original Type=FREQ                                                      COMMENT Original Unit=m / s                                                     COMMENT Original Type=VRAD                                                      COMMENT Original Unit=m / s                                                     COMMENT Original Type=VRAD                                                      TELESCOP= 'ALMA    '                                                            OBSERVER= 'pablogarciafuentes'                                                  OBSRA   =   8.490387208333E+01                                                  OBSDEC  =  -6.976674222222E+01                                                  INSTRUME= 'ALMA    '                                                            CASAVER = '6.5.4.9 '                                                            CHNCHNKS=                    7                                                  DATAMAX =   7.514491677284E-02                                                  DATAMIN =  -8.044936507940E-02                                                  DATARMS =   5.007672956174E-03                                                  DATATYPE= 'REGCAL_LINE_SCIENCE'                                                 DISTANCE=   0.000000000000E+00                                                  FIELD   = 'N159-13CII'                                                          FILNAM01= 'uid___A001_X3621_X1a6a'                                              FILNAM02= 's13_0   '                                                            FILNAM03= 'N159-13CII_sci'                                                      FILNAM04= 'spw26   '                                                            FILNAM05= 'cube    '                                                            FILNAM06= 'regcal  '                                                            FILNAM07= 'I       '                                                            FILNAM08= 'iter1   '                                                            FILNAM09= 'image   '                                                            FILNAM10= 'pbcor   '                                                            GROUP   = 'N/A     '                                                            INTENT  = 'TARGET  '                                                            ITER    =                    1                                                  MEMAVAIL=   3.655417480469E+02                                                  MEMBER  = 'uid://A001/X3621/X1a6a'                                               ...
# Parameters for the moments calculation:
# Number of channels: 3
# Velocity range: 190.0 km / s to 260.0 km / s

# %%
# Obtain essential information from the cubes
print('--------------------')
print('Información del cubo 1:')
UNIT1 = cube1.header['CUNIT3']
CRVAL1 = cube1.header['CRVAL3'] * u.km/u.s
CRPIX1 = cube1.header['CRPIX3']
CDELT1 = cube1.header['CDELT3'] * u.km/u.s
print('UNIT:', UNIT1)
print('CRVAL:', CRVAL1)
print('CRPIX:', CRPIX1)
print('CRDELT:', CDELT1)

print('--------------------')
print('Información del cubo 2:')
UNIT2 = cube2.header['CUNIT3']
RESTFRQ2 = cube2.header['RESTFRQ'] * u.Hz
CRVAL2 = cube2.header['CRVAL3'] * u.km/u.s
CRPIX2 = cube2.header['CRPIX3']
CDELT2 = cube2.header['CDELT3'] * u.km/u.s
print('UNIT en cubo 2:', UNIT2)
print('RESTFRQ en cubo 2:', RESTFRQ2)
print('CRVAL en cubo 2:', CRVAL2)
print('CRPIX en cubo 2:', CRPIX2)
print('CRDELT en cubo 2:', CDELT2)

# Obtain the number of channel
# Obtener el número de canales en los cubos
nchan1 = cube1.shape[0]
nchan2 = cube2.shape[0]
print('--------------------')
print('Número de canales en cubo 1:', nchan1)
print('Número de canales en cubo 2:', nchan2)

# Obtain speed and frequency axes
index1 = np.arange(1, nchan1 + 1)
VEL1 = CRVAL1 + (index1 - CRPIX1) * CDELT1
print('--------------------')
print('Eje de velocidad del cubo 1 (ejemplo):', VEL1[:5])

index2 = np.arange(1, nchan2 + 1)
VEL2 = CRVAL2 + (index2 - CRPIX2) * CDELT2
print('Eje de velocidad del cubo 2 (ejemplo):', VEL2[:5])
# Out:
# --------------------
# Información del cubo 1:
# UNIT: km s-1
# CRVAL: 187.0 km / s
# CRPIX: 150.0
# CRDELT: 1.0 km / s
# --------------------
# Información del cubo 2:
# UNIT en cubo 2: km s-1
# RESTFRQ en cubo 2: 102587476000.0 Hz
# CRVAL en cubo 2: -129.00000000003 km / s
# CRPIX en cubo 2: 1.0
# CRDELT en cubo 2: 1.0 km / s
# --------------------
# Número de canales en cubo 1: 300
# Número de canales en cubo 2: 729
# --------------------
# Eje de velocidad del cubo 1 (ejemplo): [38. 39. 40. 41. 42.] km / s
# Eje de velocidad del cubo 2 (ejemplo): [-129. -128. -127. -126. -125.] km / s

# %% [markdown]
# #### Generate the definition to calculate moment

# %%
def calculate_moment(cube, vel_min, vel_max, nchan, order, output_file):
    # Cortar cubo en velocidad
    subcube = cube.with_spectral_unit(u.km/u.s)
    subcube = subcube.spectral_slab(vel_min, vel_max)
    
    # Número total de canales del subcubo
    n_total_channels = subcube.shape[0]
    n_blocks = n_total_channels // nchan  # omite canales restantes
    
    # Lista para almacenar los mapas de momento
    moment_maps = []
    velocity_centers = []

    # Loop por bloques de canales
    for i in range(n_blocks):
        start = i * nchan
        end = start + nchan
        block = subcube[start:end, :, :]
        
        # Calcular el mapa de momento
        moment_map = block.moment(order=order)
        moment_maps.append(moment_map.data)  # Guardar solo los datos (array numpy)
        
        # Calcular el valor promedio de velocidad para el bloque
        vel_start = subcube.spectral_axis[start].value
        vel_end = subcube.spectral_axis[end-1].value if end <= n_total_channels else subcube.spectral_axis[-1].value
        vel_center = (vel_start + vel_end) / 2.0
        velocity_centers.append(vel_center)
    
    # Convertir la lista de mapas de momento en un cubo 3D
    moment_cube = np.stack(moment_maps, axis=0)  # Apila los mapas en el eje 0
    
    # Copiar el encabezado del cubo original
    header = copy.deepcopy(cube.header)
    
    # Modificar el encabezado para reflejar el nuevo cubo
    header['NAXIS'] = 3  # Cubo 3D
    header['NAXIS3'] = n_blocks  # Número de bloques (mapas de momento)
    header['CTYPE3'] = 'VELO-LSR'  # Eje espectral (velocidad)
    header['CUNIT3'] = 'km s-1'  # Unidad de velocidad
    header['CRVAL3'] = velocity_centers[0]  # Valor de referencia (velocidad del primer bloque)
    header['CDELT3'] = nchan  # Incremento de velocidad
    header['CRPIX3'] = 1  # Píxel de referencia
    header['BUNIT'] = f'{cube.header.get("BUNIT", "")} km s^-1' if order == 0 else cube.header.get('BUNIT', '')  # Ajustar unidad para momento 0
    
    # Mantener claves espectrales relevantes
    if 'SPECSYS' in cube.header:
        header['SPECSYS'] = cube.header['SPECSYS']  # Sistema de referencia espectral
    if 'RESTFRQ' in cube.header:
        header['RESTFRQ'] = cube.header['RESTFRQ']  # Frecuencia de reposo (si aplica)
    
    # Agregar comentario sobre los rangos de velocidad
    for i, vel in enumerate(velocity_centers, 1):
        header[f'V_CENTER{i}'] = f'{vel:.2f} km/s'
    
    # Crear el objeto HDU con los datos y el encabezado
    hdu = fits.PrimaryHDU(data=moment_cube, header=header)
    
    # Guardar el cubo en un archivo FITS
    hdu.writeto(output_file, overwrite=True)
    
    return moment_maps, velocity_centers

# %%
# ----------------- Run the function for both cubes -------------------
moment_maps1, velocity_ranges1 = calculate_moment(cube1, vel_min, vel_max, nchan, order, output_file1)
moment_maps2, velocity_ranges2 = calculate_moment(cube2, vel_min, vel_max, nchan, order, output_file2)

# Imprimir los rangos de velocidad para cada bloque
print(f'Moment maps for cube1 saved to {output_file1}')
for i, (vel_min, vel_max) in enumerate(velocity_ranges1, 1):
    print(f'Cube1 - Block {i}: Velocity range {vel_min:.2f} to {vel_max:.2f} km/s')

print(f'Moment maps for cube2 saved to {output_file2}')
for i, (vel_min, vel_max) in enumerate(velocity_ranges2, 1):
    print(f'Cube2 - Block {i}: Velocity range {vel_min:.2f} to {vel_max:.2f} km/s')
# Out:
# WARNING: VerifyWarning: Keyword name 'V_CENTER1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER2' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER3' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER4' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER5' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER6' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER7' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER8' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER9' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER10' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER11' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER12' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER13' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER14' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER15' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER16' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER17' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER18' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER19' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER20' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER21' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER22' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'V_CENTER23' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 2
#       1 # ----------------- Run the function for both cubes -------------------
# ----> 2 moment_maps1, velocity_ranges1 = calculate_moment(cube1, vel_min, vel_max, nchan, order, output_file1)
#       3 moment_maps2, velocity_ranges2 = calculate_moment(cube2, vel_min, vel_max, nchan, order, output_file2)
#       5 # Imprimir los rangos de velocidad para cada bloque
#
# Cell In[17], line 60, in calculate_moment(cube, vel_min, vel_max, nchan, order, output_file)
#      57 hdu = fits.PrimaryHDU(data=moment_cube, header=header)
#      59 # Guardar el cubo en un archivo FITS
# ---> 60 hdu.writeto(output_file, overwrite=True)
#      62 return moment_maps, velocity_centers
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\astropy\io\fits\hdu\base.py:407, in _BaseHDU.writeto(self, name, output_verify, overwrite, checksum)
#     404 from .hdulist import HDUList
#     406 hdulist = HDUList([self])
# --> 407 hdulist.writeto(name, output_verify, overwrite=overwrite, checksum=checksum)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\astropy\io\fits\hdu\hdulist.py:1033, in HDUList.writeto(self, fileobj, output_verify, overwrite, checksum)
#    1029 mode = FILE_MODES[fileobj_mode(fileobj)] if isfile(fileobj) else "ostream"
#    1031 # This can accept an open file object that's open to write only, or in
#    1032 # append/update modes but only if the file doesn't exist.
# -> 1033 fileobj = _File(fileobj, mode=mode, overwrite=overwrite)
#    1034 hdulist = self.fromfile(fileobj)
#    1035 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\astropy\io\fits\file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\astropy\io\fits\file.py:640, in _File._open_filename(self, filename, mode, overwrite)
#     638 """Open a FITS file from a filename string."""
#     639 if mode == "ostream":
# --> 640     self._overwrite_existing(overwrite, None, True)
#     642 if os.path.exists(self.name):
#     643     with open(self.name, "rb") as f:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\astropy\io\fits\file.py:521, in _File._overwrite_existing(self, overwrite, fileobj, closed)
#     519         if not closed:
#     520             fileobj.close()
# --> 521         os.remove(self.name)
#     522 else:
#     523     raise OSError(NOT_OVERWRITING_MSG.format(self.name))
#
# PermissionError: [WinError 32] El proceso no tiene acceso al archivo porque está siendo utilizado por otro proceso: 'C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/CODES/TEST/moments_cube1_nchan3.fits'

# %%
# Verificar que los archivos FITS generados se pueden abrir con SpectralCube
try:
    test_cube1 = SpectralCube.read(output_file1)
    print(f"Successfully opened {output_file1} with SpectralCube")
    print(test_cube1.header)
except Exception as e:
    print(f"Failed to open {output_file1} with SpectralCube: {e}")

try:
    test_cube2 = SpectralCube.read(output_file2)
    print(f"Successfully opened {output_file2} with SpectralCube")
    print(test_cube2.header)
except Exception as e:
    print(f"Failed to open {output_file2} with SpectralCube: {e}")
# Out:
# Successfully opened C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/CODES/TEST/moments_cube1_nchan3.fits with SpectralCube
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -64 / array data type                                NAXIS   =                    3                                                  NAXIS1  =                   70                                                  NAXIS2  =                   60                                                  NAXIS3  =                   10                                                  RESTFRQ =                  0.0                                                  VELREF  =                    0                                                  BMAJ    = 0.004444444444444444                                                  BMIN    = 0.004444444444444444                                                  BPA     =                  0.0                                                  BUNIT   = 'K km s-1'           / Brightness unit in Kelvin                      BEAM    = 'Beam: BMAJ=15.999999999999996 arcsec BMIN=15.999999999999996 &'      CONTINUE  'arcsec BPA=0.0 deg'                                                  HIERARCH V_CENTER1 = '221.00 km/s'                                              HIERARCH V_CENTER2 = '224.00 km/s'                                              HIERARCH V_CENTER3 = '227.00 km/s'                                              HIERARCH V_CENTER4 = '230.00 km/s'                                              HIERARCH V_CENTER5 = '233.00 km/s'                                              HIERARCH V_CENTER6 = '236.00 km/s'                                              HIERARCH V_CENTER7 = '239.00 km/s'                                              HIERARCH V_CENTER8 = '242.00 km/s'                                              HIERARCH V_CENTER9 = '245.00 km/s'                                              HIERARCH V_CENTER10 = '248.00 km/s'                                             WCSAXES =                    3 / Number of coordinate axes                      CRPIX1  =      43.505224439404 / Pixel coordinate of reference point            CRPIX2  =      32.760800801165 / Pixel coordinate of reference point            CRPIX3  =                  1.0 / Pixel coordinate of reference point            CDELT1  =    -0.00148148147855 / [deg] Coordinate increment at reference point  CDELT2  =     0.00148148147855 / [deg] Coordinate increment at reference point  CDELT3  =                  3.0 / [m/s] Coordinate increment at reference point  CUNIT1  = 'deg'                / Units of coordinate increment and value        CUNIT2  = 'deg'                / Units of coordinate increment and value        CUNIT3  = 'km s-1  '           / Units of coordinate increment and value        CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection           CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection               CTYPE3  = 'VOPT'               / Optical velocity (linear)                      CRVAL1  =      84.909230273958 / [deg] Coordinate value at reference point      CRVAL2  =     -69.760160218056 / [deg] Coordinate value at reference point      CRVAL3  =                221.0 / [m/s] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =     -69.760160218056 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = 'ICRS'               / Equatorial coordinate system                   SPECSYS = 'LSRK'               / Reference frame of spectral coordinates        COMMENT Original Unit=m / s                                                     COMMENT Original Type=VELO                                                      HISTORY Written by spectral_cube v0.6.6 on 2025/08/28-12:49:25                  END                                                                                                                                                              ...
# Successfully opened C:/Users/macka/OneDrive/Documentos/Master/PYTHON_CODES/CODES/TEST/moments_cube2_nchan3.fits with SpectralCube
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -64 / array data type                                NAXIS   =                    3                                                  NAXIS1  =                   70                                                  NAXIS2  =                   60                                                  NAXIS3  =                   10                                                  BMAJ    = 0.004444444444444444                                                  BMIN    = 0.004444444444444444                                                  BPA     =                  0.0                                                  BTYPE   = 'Intensity'                                                           OBJECT  = 'N159-13CII'                                                          BUNIT   = 'K km s-1'           / Brightness unit in Jy/beam                     ALTRVAL =   5.990705566226E+05 /Alternate frequency reference value             ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel             VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio                 COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL                 COMMENT Original Unit=Hz                                                        COMMENT Original Type=FREQ                                                      COMMENT Original Unit=m / s                                                     COMMENT Original Type=VRAD                                                      COMMENT Original Unit=m / s                                                     COMMENT Original Type=VRAD                                                      TELESCOP= 'ALMA    '                                                            OBSERVER= 'pablogarciafuentes'                                                  OBSRA   =   8.490387208333E+01                                                  OBSDEC  =  -6.976674222222E+01                                                  INSTRUME= 'ALMA    '                                                            CASAVER = '6.5.4.9 '                                                            CHNCHNKS=                    7                                                  DATAMAX =   7.514491677284E-02                                                  DATAMIN =  -8.044936507940E-02                                                  DATARMS =   5.007672956174E-03                                                  DATATYPE= 'REGCAL_LINE_SCIENCE'                                                 DISTANCE=   0.000000000000E+00                                                  FIELD   = 'N159-13CII'                                                          FILNAM01= 'uid___A001_X3621_X1a6a'                                              FILNAM02= 's13_0   '                                                            FILNAM03= 'N159-13CII_sci'                                                      FILNAM04= 'spw26   '                                                            FILNAM05= 'cube    '                                                            FILNAM06= 'regcal  '                                                            FILNAM07= 'I       '                                                            FILNAM08= 'iter1   '                                                            FILNAM09= 'image   '                                                            FILNAM10= 'pbcor   '                                                            GROUP   = 'N/A     '                                                            INTENT  = 'TARGET  '                                                            ITER    =                    1                                                  MEMAVAIL=   3.655417480469E+02                                                  MEMBER  = 'uid://A001/X3621/X1a6a'                                               ...
